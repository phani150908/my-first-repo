# %% [markdown]
# Differences between hardware and software ?
# Hardware refers to the physical parts of a computer like the keyboard,monitor,and CPU that u can touch.Software ios the set of programs and instructions that tell the hardware what to do such as apps and operating systems.hardware cannot function without software,and software  needs hardware to run.
